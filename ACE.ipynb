# %%
import tropycal.tracks as tracks
import datetime as dt

# %%
ibtracs = tracks.TrackDataset(basin='west pacific',source='ibtracs',ibtracs_mode='jtwc_neumann',
                              ibtracs_url="/mnt/chromeos/removable/My Passport/Python/ibtracs.WP.list.v04r00.txt")
# Out:
# --> Starting to read in ibtracs data
# --> Completed reading in ibtracs data (73.44 seconds)

# %%
storm = ibtracs.get_storm(('tip',1979))
season= ibtracs.get_season(2017)

#print(storm)

# %%
ibtracs.ace_climo(plot_year=2018,compare_years=2017)
# Out:
# /opt/miniconda3/lib/python3.7/site-packages/tropycal/tracks/dataset.py:1368: UserWarning: This function is not currently configured to work for the ibtracs dataset.
#   warnings.warn("This function is not currently configured to work for the ibtracs dataset.")

# %%
ibtracs.ace_climo(plot_year=2020,compare_years=2019)
# Out:
# /opt/miniconda3/lib/python3.7/site-packages/tropycal/tracks/dataset.py:1368: UserWarning: This function is not currently configured to work for the ibtracs dataset.
#   warnings.warn("This function is not currently configured to work for the ibtracs dataset.")
