# %%
#import modules to make the map work

import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
#set where the map data is pulled from

#from cartopy.io.img_tiles import Stamen

# %%
#def main():
#    tiler = Stamen('terrain-background')
#    mercator = tiler.crs
#    
#    fig = plt.figure()
#    ax  = fig.add_subplot(1, 1, 1, projection=mercator) #size of map
#    ax.set_extent([130, 140, 5, 15], crs=ccrs.PlateCarree()) #map location
#    
#    ax.add_image(tiler, 6)
#    plt.show()
#    
#if __name__ == '__main__':
#    main()

# %%
ax = plt.axes(projection=ccrs.PlateCarree())
ax.stock_img()

# %%
# Out:
# <GeoAxesSubplot:>
