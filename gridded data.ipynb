# %%
#import modules

import tropycal as tp
import tropycal.tracks as tracks
import datetime as dt

# %%
#pull in data from external drive
ibtracs = tracks.TrackDataset(basin='all',source='ibtracs',ibtracs_mode='jtwc',
                              ibtracs_url="/mnt/chromeos/removable/My Passport/Python/ibtracs.WP.list.v04r00.txt")
# Out:
# --> Starting to read in ibtracs data
# --> Completed reading in ibtracs data (65.31 seconds)

# %%
#create max wind gtaphic for west Pacific

ibtracs.gridded_stats(request="maximum wind",return_ax=True,prop={'cmap':'plasma_r'},domain="west_pacific")
# Out:
# --> Getting filtered storm tracks
# --> Grouping by lat/lon/storm
# /opt/miniconda3/lib/python3.7/site-packages/tropycal/tracks/tools.py:101: RuntimeWarning: All-NaN slice encountered
#   return thresh, lambda x: np.nanmax(x)
# /opt/miniconda3/lib/python3.7/site-packages/tropycal/tracks/tools.py:101: RuntimeWarning: All-NaN axis encountered
#   return thresh, lambda x: np.nanmax(x)
# /opt/miniconda3/lib/python3.7/site-packages/cartopy/mpl/gridliner.py:307: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /opt/miniconda3/lib/python3.7/site-packages/cartopy/mpl/gridliner.py:343: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# ...

# %%
#create graph for minimum pressure in the west pacific

ibtracs.gridded_stats(request="Minimum pressure",prop={'cmap':'plasma_r'},domain="west_pacific")
# Out:
# --> Getting filtered storm tracks
# --> Grouping by lat/lon/storm
# /opt/miniconda3/lib/python3.7/site-packages/tropycal/tracks/tools.py:105: RuntimeWarning: All-NaN slice encountered
#   return thresh, lambda x: np.nanmin(x)
# /opt/miniconda3/lib/python3.7/site-packages/tropycal/tracks/tools.py:105: RuntimeWarning: All-NaN axis encountered
#   return thresh, lambda x: np.nanmin(x)
# --> Generating plot

# %%
#ibtracs.gridded_stats(request="number of storms",prop={'cmap':'plasma_r'},domain="west_pacific")

# %%
#h = tracks.TrackDatasethurricane_days_climo(plot_year=2019)
